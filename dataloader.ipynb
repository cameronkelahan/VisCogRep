# %%
import numpy as np
from PIL import Image
import os

# img = Image.open('./iccv09Data/images/0000047.jpg')
# arr = np.array(img) # 640x480x4 array
# # arr[20, 30] # 4-vector, just like above

# print(arr.shape)
# img

directory_path = './iccv09Data/images/'
image_dataset = []
image_array_dataset = []

for filename in os.listdir(directory_path):
    image_path = os.path.join(directory_path, filename)

    try:
        image = Image.open(image_path)
        image_dataset.append(image)
        image_array_dataset.append(np.array(image))
    except Exception as e:
        print(f"Error loading image {filename}: {e}")

print(len(image_dataset))
print(len(image_array_dataset))
print(type(image_array_dataset[0]))
example = image_dataset[0]
example
# Out:
# 715
# 715
# <class 'numpy.ndarray'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>
